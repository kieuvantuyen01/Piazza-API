# %%
# !pip install piazza-api
# !pip install html2text
# !pip install pandas
# !pip install openpyxl
# Out:
# Requirement already satisfied: piazza-api in ./.venv/lib/python3.12/site-packages (0.14.1)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from piazza-api) (2.32.2)
# Requirement already satisfied: six in ./.venv/lib/python3.12/site-packages (from piazza-api) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->piazza-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->piazza-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->piazza-api) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->piazza-api) (2024.2.2)
# Requirement already satisfied: html2text in ./.venv/lib/python3.12/site-packages (2024.2.26)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import json
import re
import os
import time
from html2text import HTML2Text
from piazza_api import Piazza
import pandas as pd
from datetime import datetime

HTML_2_TEXT = HTML2Text()
HTML_2_TEXT.ignore_links = True

EMAIL = None
PASSWORD = None
NETWORK_ID = None

if os.path.exists('credentials.json'):
    with open('credentials.json') as f:
        credentials = json.load(f)
        EMAIL = credentials.get('email', None)
        PASSWORD = credentials.get('password', None)
        NETWORK_ID = credentials.get('network_id', None)

def count_good_comments(comment, student_comment_counts, user_id_to_name):
    if (comment['type'] == 'followup' or comment['type'] == 'feedback') and comment['tag_good']:
        student_id = comment.get('uid', None)
        if student_id and student_id not in student_comment_counts:
            student_comment_counts[student_id] = 0
        if student_id:
            student_comment_counts[student_id] += 1
            if student_id not in user_id_to_name:
                user_id_to_name[student_id] = "Unknown"
    for child in comment['children']:
        count_good_comments(child, student_comment_counts, user_id_to_name)

def main():
    """
    This function performs the main logic of the program.
    It logs in to Piazza, retrieves posts and comments, and exports the data to an Excel file.
    """

    piazza = Piazza()
    piazza.user_login(email=EMAIL, password=PASSWORD)
    print("Logged in successfully.")
    network_id = NETWORK_ID
    course = piazza.network(network_id)
    posts = list(course.iter_all_posts(limit=500))  # Convert generator to list
    print(posts)
    print(f"Found {len(posts)} posts.")

    # Get all users and create a dictionary mapping user IDs to names and emails
    all_users = course.get_all_users()
    user_id_to_name = {user['id']: user['name'] for user in all_users}
    user_id_to_email = {user['id']: user['email'] for user in all_users}

    student_comment_counts = {}

    for post in posts:
        for child in post['children']:
            count_good_comments(child, student_comment_counts, user_id_to_name)
        # time.sleep(1)  # Add a delay between requests

    # Prepare data for DataFrame
    data = []
    for uid, count in student_comment_counts.items():
        student_name = user_id_to_name.get(uid, "Unknown")
        student_email = user_id_to_email.get(uid, "Unknown")
        student_id = student_email.split('@')[0] if student_email != "Unknown" else "Unknown"
        data.append([student_id, student_name, count])
        print(f"Student {student_name} ({uid}) with ID {student_id} has {count} helpful comments.")

    # Create DataFrame and export to Excel
    df = pd.DataFrame(data, columns=['ID', 'Họ Tên', 'Số câu trả lời đúng'])
    df.to_excel(f"{datetime.now().strftime('%Y%m%d%H%M%S')}.xlsx", index=False)

if __name__ == '__main__':
    main()
# Out:
# Logged in successfully.
# [{'history_size': 1, 'folders': [], 'nr': 5, 'data': {'embed_links': []}, 'created': '2024-02-20T09:28:45Z', 'bucket_order': 0, 'no_answer_followup': 0, 'change_log': [{'anon': 'no', 'uid': 'gd6v7134AUa', 'data': 'lsu5y3k0lul7ii', 'v': 'private', 'type': 'create', 'when': '2024-02-20T09:28:45Z'}], 'bucket_name': 'Pinned', 'history': [{'anon': 'no', 'uid': 'gd6v7134AUa', 'subject': 'Search for Teammates!', 'created': '2024-02-20T09:28:45Z', 'content': '<script type="text/javascript">PA.load("/dashboard/project_partners", null, function(data){ $(\'#\' + \'questionText\').html(data);});</script> #pin'}], 'type': 'note', 'anon_map': {}, 'tags': ['pin', 'student'], 'tag_good': [], 'unique_views': 1, 'children': [], 'tag_good_arr': [], 'anon_icons': True, 'id': 'lsu5y3jryuq7ig', 'config': {'feed_groups': 'instr_lsu5y35oppg7hs', 'is_default': 1}, 'status': 'private', 'drafts': None, 'request_instructor': 0, 'request_instructor_me': False, 'bookmarked': 0, 'num_favorites': 0, 'my_favorite': False, 'is_bookmarked': False, 'is_tag_good': False, 'q_edits': [], 'i_edits': [], 's_edits': [], 't': 1716885950426, 'default_anonymity': 'no'}, {'history_size': 3, 'folders': ['other'], 'nr': 60, 'data': {'embed_links': []}, 'created': '2024-05-26T14:42:23Z', 'bucket_order': 3, 'no_answer_followup': 0, 'change_log': [{'anon': 'no', 'uid': 'lmbhczecqs86rr', 'data': 'lwnnf74ts2g6p4', 'v': 'all', 'type': 'create', 'when': '2024-05-26T14:42:23Z'}, {'anon': 'no', 'uid': 'lmbhczecqs86rr', 'data': 'lwnnkdasyz23p', 'v': 'all', 'type': 'update', 'when': '2024-05-26T14:46:24Z'}, {'anon': 'no', 'uid': 'lmbhczecqs86rr', 'data': 'lwnnnec9o9m3ok', 'v': 'all', 'type': 'update', 'when': '2024-05-26T14:48:45Z'}], 'bucket_name': 'Today', 'history': [{'anon': 'no', 'uid': 'lmbhczecqs86rr', 'subject': 'Thông báo về Lịch buổi Ôn tập online &#43; Cách thức tính điểm môn học', 'created': '2024-05-26T14:48:45Z', 'content': '<p>Thân chào các em,</p>\n<p></p>\n<p>Về Lịch Ôn tập Online, thời gian diễn ra từ <strong>21h00</strong> tối <strong>thứ Tư</strong>, ngày <strong>29/05/2024</strong>. Nội dung: làm đề Ôn tập.</p>\n<p>Link meeting: <a href="https://teams.microsoft.com/l/meetup-join/19%3ayyO2pKwtz2jJz-RqpIhOyuwYyH1vFHtGHgspLKBRn7c1%40thread.tacv2/1716734737081?context=%7b%22Tid%22%3a%225e158e2a-0596-4a6c-8801-3502aef4563f%22%2c%22Oid%22%3a%22a4e9da00-69d9-4f6f-8cad-1622922faebf%22%7d" target="_blank" rel="noopener noreferrer">Link</a></p>\n<p>Dựa vào điểm OASIS, anh có cân nhắc sau:</p>\n<ul><li>Nếu điểm GK &lt; OASIS, GK = (GK &#43; OASIS)/2</li><li>Điểm Thực hành = OASIS &#43; Điểm dư (BTL) &#43; Điểm cộng (Piazza), nếu Điểm Thực hành &gt; 10 thì Điểm Thực hành\xa0 = 10</li></ul>\n<div>\n<div>Về hệ số các đầu điểm: do thầy Khánh quyết định.</div>\n</div>\n<p>Hạn cuối lấy điểm OASIS: Hết ngày <strong>09/06/2024</strong></p>\n<p>Về điểm cộng trên Piazza, anh sẽ tổng hợp sau khi lấy được điểm OASIS final.</p>\n<p></p>\n<p>Có vấn đề gì thắc mắc, phiền các em phản hồi sớm để được giải quyết.</p>\n<p>Best,</p>\n<p>Anh Tuyên</p>\n<div>\n<p>https://teams.microsoft.com/l/meetup-join/19%3ayyO2pKwtz2jJz-RqpIhOyuwYyH1vFHtGHgspLKBRn7c1%40thread.tacv2/1716734737081?context=%7b%22Tid%22%3a%225e158e2a-0596-4a6c- 8801-3502aef4563f%22 %2c%22Oid%22%3a%22a4e9da00-69d9-4f6f-8cad-1622922faebf%22%7d</p>\n</div>'}, {'anon': 'no', 'uid': 'lmbhczecqs86rr', 'subject': 'Thông báo về Lịch buổi Ôn tập online &#43; Cách thức tính điểm môn học', 'created': '2024-05-26T14:46:24Z', 'content': '<p>Thân chào các em,</p>\n<p></p>\n<p>Về Lịch Ôn tập Online, thời gian diễn ra từ <strong>21h00</strong> tối <strong>thứ Tư</strong>, ngày <strong>29/05/2024</strong>. Nội dung: làm đề Ôn tập.</p>\n<p>Link meeting: <a href="https://teams.microsoft.com/l/meetup-join/19%3ayyO2pKwtz2jJz-RqpIhOyuwYyH1vFHtGHgspLKBRn7c1%40thread.tacv2/1716734737081?context=%7b%22Tid%22%3a%225e158e2a-0596-4a6c-8801-3502aef4563f%22%2c%22Oid%22%3a%22a4e9da00-69d9-4f6f-8cad-1622922faebf%22%7d" target="_blank" rel="noopener noreferrer">L ...
# Found 60 posts.
# Student Nguyễn Văn Huy (lsu676qsoz71tz) with ID 23020379 has 3 helpful comments.
# Student Vũ Đức Huy (lsu677jw1c1w5) with ID 23020380 has 2 helpful comments.
# Student Nguyễn Văn Linh (lsu67896pn1xv) with ID 23020395 has 1 helpful comments.
# Student Tô Tiến Đạt (lsu677ust8j1wu) with ID 23020353 has 3 helpful comments.
# Student Vu Duc Minh (lsu677ggslq1vw) with ID 23020401 has 2 helpful comments.
# Student Cuongngucute (lsu676jh8wk1te) with ID 23020339 has 2 helpful comments.
# Student Phạm Hà Anh (lsu675ga5a11qg) with ID 23020330 has 1 helpful comments.
# Student Phạm Ngọc Hải Dương (lsu677szd3m1wq) with ID 23021513 has 1 helpful comments.
# Student Nguyễn Phương Nam (lsu675w9jl91rn) with ID 23020406 has 7 helpful comments.
# Student Tran Doan Thang (lsu6768ze2i1sk) with ID 23020438 has 2 helpful comments.
# Student Mai Minh Tùng (lsu676sh7ho1u3) with ID 23020432 has 1 helpful comments.
# Student Mai Phan Anh Tùng (lsu674n8dc61o9) with ID 23020433 has 2 helpful comments.
# Student Nguyễn Đức Huy (lsu67823tnz1xd) with ID 23020376 has 1 helpful comments.
# Student Tạ Quang Linh (lsu677wkrfp1x1) with ID 23020396 has 1 helpful comments.
# Student Nguyễn Khánh Tùng (lsu675i1no81ql) with ID 23020434 has 1 helpful comments.
# Student Đặng Minh Nguyệt (lsu675ljlpy1qt) with ID 23020407 has 1 helpful comments.
# Student Dương Minh Kiên (lsu676cku721st) with ID 22022217 has 1 helpful comments.
# Student Phạm Thế Trung (lsu676uafa01u8) with ID 23020442 has 2 helpful comments.
# Student Kiều Văn Tuyên (lmbhczecqs86rr) with ID tuyenkv has 5 helpful comments.
# Student Trịnh Tuấn Ngọc Bảo (lsu6783yo461xh) with ID 23020333 has 3 helpful comments.
# Student Phan Quang Trường (lsu674lbvp51m2) with ID 23020443 has 1 helpful comments.
# Student Hoàng Văn Dương (lsu676n6xi51tr) with ID 23020349 has 1 helpful comments.
# Student Nguyễn Văn Việt (lsu675989n31pw) with ID 23020444 has 1 helpful comments.
# Student Nguyễn Gia Huy (lsu673xao441ii) with ID 23020377 has 1 helpful comments.
# Student Luong Minh Tri (lsu674676611j5) with ID 23020440 has 1 helpful comments.
# Student Vu Nguyen Dan (lsu674yojkg1p5) with ID 23020351 has 2 helpful comments.
